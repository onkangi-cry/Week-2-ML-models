# %% [markdown]
# <a href="https://colab.research.google.com/github/onkangi-cry/Week-2-ML-models/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Computer vision enables a computer to mske decisions based on visual  inputs from the world
# It uses videos and images to make decisions.
# The core tasks include
# 1.Assign a label to an entire image
# 2.Locate multiply objects within an image
# 3.Classify each pixel into predefined categories and state if there are multiple instances of the same object
# 4.Create or refine the existing images
# Now we can transfer our model to a larger dataset to do specific tasks
# We are going to use open cv

# Rhe first step always is to import necessary libraries
# OpenCv is for computer vision while matplot lib for plotting images
import cv2
# cv2 helps us see things in images
import matplotlib.pyplot as plt

# The next step is then to load our data from a dataset
image = cv2.imread(r"C:\Users\john\Desktop\Again\headshot.jpg")
# Now we can check if our image is present
if image is None:
  print("Error.Unable to find the image")
else:
  # We  convert our image to grayscale which removes RBG and just the computer works with brightness making it easier to process data.
  # CVT COLOR does the conversion
  gray_image=cv2.cvtColor(image,cv2.COLOR_BG2BGRAY)
# Now we apply the canny detection which is able to find the edges by detecting areas of great intensity
  edges = cv2.Canny(gray_image, threshold1=100, threshold2=200)
plt.figure(figsize=(10, 5))
# It creates a canvas whwere our results will be posted
plt.subplot(1,2,1)
# Tells python divide the canvas into 1 row 2 columns and go to the first slot
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis("off")
# Tells python divide the canvas into 1 row 2 columns and go to the second
# Out:
# Error.Unable to find the image
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-19-1352387755.py in <cell line: 0>()
#      30 plt.subplot(1,2,1)
#      31 # Tells python divide the canvas into 1 row 2 columns and go to the first slot
# ---> 32 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#      33 plt.title('Original Image')
#      34 plt.axis("off")
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2

# Load the image
image = cv2.imread("C:/Users/john/Desktop/Again/headshot.jpg")  # Replace with your full image path

# Check if the image is loaded
if image is None:
    print("Image not found or path is incorrect.")
else:
    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Canny edge detection
    edges = cv2.Canny(gray_image, threshold1=100, threshold2=200)

    # Display the edges
    cv2.imshow("Edges", edges)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Image not found or path is incorrect.

# %%
# Computer vision enables a computer to mske decisions based on visual  inputs from the world
# It uses videos and images to make decisions.
# The core tasks include
# 1.Assign a label to an entire image
# 2.Locate multiply objects within an image
# 3.Classify each pixel into predefined categories and state if there are multiple instances of the same object
# 4.Create or refine the existing images
# Now we can transfer our model to a larger dataset to do specific tasks
# We are going to use open cv

# Rhe first step always is to import necessary libraries
# OpenCv is for computer vision while matplot lib for plotting images
import cv2
# cv2 helps us see things in images
import matplotlib.pyplot as plt

# The next step is then to load our data from a dataset
# Make sure the path points to an actual image file, not just a directory
image = cv2.imread(r"C:\Users\john\Desktop\Again\headshot.jpg") # Replace 'your_image_file.jpg' with the name of your image file
# Now we can check if our image is present
if image is None:
  print("Error.Unable to find the image. Please check the file path.")
else:
  # We  convert our image to grayscale which removes RBG and just the computer works with brightness making it easier to process data.
  # CVT COLOR does the conversion
  gray_image=cv2.cvtColor(image,cv2.COLOR_BG2GRAY) # Corrected COLOR_BG2BGRAY to COLOR_BGR2GRAY

  # Now we apply the canny detection which is able to find the edges by detecting areas of great intensity
  # Move this line inside the else block so it's only executed when gray_image is defined
  edges = cv2.Canny(gray_image, threshold1=100, threshold2=200)

  # You can now work with the 'edges' variable here, for example, display it
  # plt.imshow(edges, cmap='gray')
  # plt.title('Canny Edges')
  # plt.show()

# %%
# Import necessary libraries:
import cv2          # OpenCV library for computer vision.
import matplotlib.pyplot as plt  # For plotting images using matplotlib.

# Load a sample image from disk.
# Replace 'sample.jpg' with the path to an actual image file.
image = cv2.imread(r"C:\Users\john\Desktop\Again\headshot.jpg")
# imread loads the image in BGR (Blue, Green, Red) format.

# Check if the image was correctly loaded.
if image is None:
    print("Error: Unable to load image file.")
else:
    # Convert image to grayscale.
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # cvtColor converts the image from BGR to Grayscale.

    # Apply Canny edge detection.
    edges = cv2.Canny(gray_image, threshold1=100, threshold2=200)
    # Canny detects edges by finding areas of strong intensity gradients.

    # Display the original and edge-detected images side by side.
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display.
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(edges, cmap='gray')
    plt.title('Edge Detection')
    plt.axis('off')

    plt.show()
# Out:
# Error: Unable to load image file.

# %%
import os

path = r"C:\Users\john\Desktop\Again\headshot.jpg"
print("File exists?", os.path.exists(path))
# Out:
# File exists? False

# %%
 # Import the turtle module:
import turtle

# Create a turtle object to represent our robot.
robot = turtle.Turtle()
robot.shape("turtle")   # Set the shape to "turtle" for visual clarity.
robot.speed(2)          # Control the drawing speed (1-slowest, 10-fastest).

# Define functions to control the robot's motion:
def go_forward():
    """Moves the robot forward by 20 pixels."""
    robot.forward(20)

def go_backward():
    """Moves the robot backward by 20 pixels."""
    robot.backward(20)

def turn_left():
    """Turns the robot left by 30 degrees."""
    robot.left(30)

def turn_right():
    """Turns the robot right by 30 degrees."""
    robot.right(30)

# Set up the screen to listen to key presses.
screen = turtle.Screen()
screen.title("Simple Robot Teleoperation Demo")
screen.listen()  # Enable keyboard event listening.

# Bind the arrow keys to the corresponding functions.
screen.onkey(go_forward, "Up")    # When the "Up" arrow key is pressed, call go_forward().
screen.onkey(go_backward, "Down") # When the "Down" arrow key is pressed, call go_backward().
screen.onkey(turn_left, "Left")   # When the "Left" arrow key is pressed, call turn_left().
screen.onkey(turn_right, "Right") # When the "Right" arrow key is pressed, call turn_right().

# Keep the window open until it is closed by the user.
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-24-1407067669.py in <cell line: 0>()
#       3
#       4 # Create a turtle object to represent our robot.
# ----> 5 robot = turtle.Turtle()
#       6 robot.shape("turtle")   # Set the shape to "turtle" for visual clarity.
#       7 robot.speed(2)          # Control the drawing speed (1-slowest, 10-fastest).
#
# /usr/lib/python3.11/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3828                  visible=_CFG["visible"]):
#    3829         if Turtle._screen is None:
# -> 3830             Turtle._screen = Screen()
#    3831         RawTurtle.__init__(self, Turtle._screen,
#    3832                            shape=shape,
#
# /usr/lib/python3.11/turtle.py in Screen()
#    3678     else return the existing one."""
#    3679     if Turtle._screen is None:
# ...

# %%
# Import the turtle module:
import turtle

# Create a turtle object to represent our robot.
robot = turtle.Turtle()
robot.shape("turtle")   # Set the shape to "turtle" for visual clarity.
robot.speed(2)          # Control the drawing speed (1-slowest, 10-fastest).

# Define functions to control the robot's motion:
def go_forward():
    """Moves the robot forward by 20 pixels."""
    robot.forward(20)

def go_backward():
    """Moves the robot backward by 20 pixels."""
    robot.backward(20)

def turn_left():
    """Turns the robot left by 30 degrees."""
    robot.left(30)

def turn_right():
    """Turns the robot right by 30 degrees."""
    robot.right(30)

# Set up the screen to listen to key presses.
screen = turtle.Screen()
screen.title("Simple Robot Teleoperation Demo")
screen.listen()  # Enable keyboard event listening.

# Bind the arrow keys to the corresponding functions.
screen.onkey(go_forward, "Up")    # When the "Up" arrow key is pressed, call go_forward().
screen.onkey(go_backward, "Down") # When the "Down" arrow key is pressed, call go_backward().
screen.onkey(turn_left, "Left")   # When the "Left" arrow key is pressed, call turn_left().
screen.onkey(turn_right, "Right") # When the "Right" arrow key is pressed, call turn_right().

# Keep the window open until it is closed by the user.
# turtle.done() # This is a blocking call, might need to handle carefully in notebook
screen.mainloop() # Using screen.mainloop() is also an option
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipython-input-25-2977639469.py in <cell line: 0>()
#       3
#       4 # Create a turtle object to represent our robot.
# ----> 5 robot = turtle.Turtle()
#       6 robot.shape("turtle")   # Set the shape to "turtle" for visual clarity.
#       7 robot.speed(2)          # Control the drawing speed (1-slowest, 10-fastest).
#
# /usr/lib/python3.11/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3828                  visible=_CFG["visible"]):
#    3829         if Turtle._screen is None:
# -> 3830             Turtle._screen = Screen()
#    3831         RawTurtle.__init__(self, Turtle._screen,
#    3832                            shape=shape,
#
# /usr/lib/python3.11/turtle.py in Screen()
#    3678     else return the existing one."""
#    3679     if Turtle._screen is None:
# ...

# %%
# The first step is to always import all the necessary libraries
# numpy is good with numbers and we are working with data
# sk learn has datasets and make _classification will be used to test classifications
# matplot lib is for drawing graphs
# logistic regression is used to is a linear model that learns patterns
# classification report shows how good our model learned
import numpy as np
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
# We can then create 200 fake data points to see how our model runs
X,y =make_classification(
    n_samples=200,
    n_features=2,
    # Each dot has 2 special features left/right and up/down
    n_redundant=0,
    # There is no silly data
    # n_informative=Both things will help tell the yellow from the red
    n_clusters_per_class=1,
    # Keep each color in one main group
    random_state=42
    # Keep the results the same each time you run
)
# Now we will draw our data points
# First we draw the x and y axis
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.title('Synthetic Classification of Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# I will create a classifier model
clf=LogisticRegression()
# I will now train my model to look the x values and the answers it obtains in y to learn how to predict them
clf.fit(X,y)
# fit is used to learn patterns
# Now after training our model we can make predictions from x
y_pred=clf.predict(X)
# Now we can evaluate how good our model is
print(classification_report(y,y_pred))
# y,y_pred means the actual y and the predicted y
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       100
#            1       0.83      0.85      0.84       100
#
#     accuracy                           0.84       200
#    macro avg       0.84      0.84      0.84       200
# weighted avg       0.84      0.84      0.84       200

# %%
# In unsupervised learning we make use of unlabeled data and our model learns the hidden patterns and later be able to sepatarate fraudulent transcations.
# K-means is used to cluster points i.e if I spill 3000 jelly beans on the table I can use this model to  group them into 3 major colors and place them in bowls
# The first step I will do is to make fake clustered data using make-blobs plot it and group it using k means
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
# Remember we are using unlabelled data
# So we have points X and we want to pretend that we dont see the labels
X,_=make_blobs(n_samples=300,centers=3,cluster_std=0.60,random_state=42)
# Now we will apply our KMeans
KMeans=KMeans(n_clusters=3,random_state=42)
KMeans.fit(X)
# We can give labels to our clusters
clusters=KMeans.labels_
# Now let us plot our result
plt.scatter(X[:,0],X[:,1], c=clusters,cmap='viridis',edgecolor='k')

# %%
# REINFORCMENT LEARNING

# %%
# We impo[rt libraries
import gym
# Let us interact with platforms like frozen lake where AI agents can learn and play
import numpy as np
# Now we make an environment where our model will learn from
env=gym.make("FrozenLake-v1",is_slippery=False)
# Now we want our model tpo walk and learn by evading holes and reaching the goal
Q_table=np.zeros((env.observation_space.n,env.action_space.n))
# Is like saying for instance that we are creating an environment with different roooms or observations where different action can take place
# Now let us set our parameters
n_episodes=2000
# The number of times our agent trains from scratch
max_steps=100
# How far our agent can move in one episode
learning_rate=0.8
# How good to accept new info 0 dont and 1 yes do
discount_factor=0.95
# How much our agent cares about a future reward
epsilon=1.0
max_epsilon=1
min_epsilon=0.01
# Epsilon is how much our agent is expected to be random with 1 being fully random
decay_rate=0.005
# How fast the randomness fades.
for episode in range(n_episodes):
  state=env.reset()
  done=False
  # We are to train our agent again and again.the agent hasnt won or fallen off
  # Now we want our model to either explore or exploit moves
for atep in (max_steps):
  exp_exp_tradeoff=np.random.uniform(0,1)
  if exp_exp_tradeoff>epsilon:
    action=np.argmax(Q_table)
  # If you are feeling more smart hence less random go on with the best option but if not explore a new path
  # Update the Q-table using the Q-learning update rule:
        # Q(s, a) = Q(s, a) + learning_rate * [reward + discount * max(Q(new_state)) - Q(s, a)]
        Q_table[state, action] = Q_table[state, action] + learning_rate * (
            reward + discount_factor * np.max(Q_table[new_state, :]) - Q_table[state, action]
        )

        # Transition to the new state.
        state = new_state

        # If the episode is finished (reached a terminal state), exit the loop.
        if done:
            break

    # Decay epsilon after each episode.
    # This gradually reduces exploration as the agent learns more about the environment.
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode)

# After training, print the final Q-table.
print("Trained Q-table:")
print(Q_table)

# --- Testing the trained agent ---
state = env.reset()  # Reset the environment for testing.
total_reward = 0     # Initialize reward accumulator.
for step in range(max_steps):
    # Always select the best action based on the current Q-table (exploitation).
    action = np.argmax(Q_table[state, :])
    new_state, reward, done, info = env.step(action)
    total_reward += reward  # Accumulate the reward.
    state = new_state       # Move to the next state.
    if done:
        break

print("Total reward earned during test:", total_reward)
# Out:
#   File "/tmp/ipython-input-1-1328074992.py", line 37
#     Q_table[state, action] = Q_table[state, action] + learning_rate * (
#     ^
# IndentationError: unexpected indent

# %%
# Import the gym library for the environment and numpy for numerical operations.
import gym
import numpy as np

# Create the FrozenLake environment.
# 'is_slippery=False' makes the environment deterministic (simpler for demonstration).
env = gym.make("FrozenLake-v1", is_slippery=False)

# Initialize the Q-table with zeros.
# Rows correspond to states and columns to possible actions.
Q_table = np.zeros((env.observation_space.n, env.action_space.n))

# Set hyperparameters for the Q-learning algorithm.
n_episodes = 2000       # Total episodes to run the training.
max_steps = 100         # Maximum steps per episode.
learning_rate = 0.8     # Learning rate to control update magnitude.
discount_factor = 0.95  # Discount factor for future rewards.
epsilon = 1.0           # Exploration rate (starting value).
max_epsilon = 1.0       # Maximum exploration probability.
min_epsilon = 0.01      # Minimum exploration probability.
decay_rate = 0.005      # Exponential decay rate for epsilon.

# Q-learning algorithm:
for episode in range(n_episodes):
    state = env.reset()  # Reset environment for a new episode.
    done = False         # Indicator whether the episode is finished.

    for step in range(max_steps):
        # Generate a random number to decide whether to explore or exploit.
        exp_exp_tradeoff = np.random.uniform(0, 1)

        # Epsilon-greedy strategy:
        # If the random number is greater than epsilon, we exploit (choose best action).
        # Otherwise, we explore by selecting a random action.
        if exp_exp_tradeoff > epsilon:
            action = np.argmax(Q_table[state, :])  # Best known action.
        else:
            action = env.action_space.sample()      # Random action.

        # Take the chosen action, and observe the next state, reward, and if the episode is done.
        # new_state, reward, done, info = env.step(action)

        # Update the Q-table using the Q-learning update rule:
        # Q(s, a) = Q(s, a) + learning_rate * [reward + discount * max(Q(new_state)) - Q(s, a)]
        Q_table[state, action] = Q_table[state, action] + learning_rate * (
            reward + discount_factor * np.max(Q_table[new_state, :]) - Q_table[state, action]
        )

        # Transition to the new state.
        state = new_state

        # If the episode is finished (reached a terminal state), exit the loop.
        if done:
            break

    # Decay epsilon after each episode.
    # This gradually reduces exploration as the agent learns more about the environment.
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode)

# After training, print the final Q-table.
print("Trained Q-table:")
print(Q_table)

# --- Testing the trained agent ---
state = env.reset()  # Reset the environment for testing.
total_reward = 0     # Initialize reward accumulator.
for step in range(max_steps):
    # Always select the best action based on the current Q-table (exploitation).
    action = np.argmax(Q_table[state, :])
    new_state, reward, done, info = env.step(action)
    total_reward += reward  # Accumulate the reward.
    state = new_state       # Move to the next state.
    if done:
        break

print("Total reward earned during test:", total_reward)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-2745732879.py in <cell line: 0>()
#      44         # Q(s, a) = Q(s, a) + learning_rate * [reward + discount * max(Q(new_state)) - Q(s, a)]
#      45         Q_table[state, action] = Q_table[state, action] + learning_rate * (
# ---> 46             reward + discount_factor * np.max(Q_table[new_state, :]) - Q_table[state, action]
#      47         )
#      48
#
# NameError: name 'reward' is not defined

# %%
# Import the necessary libraries.
import numpy as np                           # For numerical operations and random number generation.
from sklearn import datasets                # To generate a toy dataset (make_moons).
import matplotlib.pyplot as plt             # To visualize the dataset and results.
from sklearn.semi_supervised import LabelSpreading  # The semi-supervised learning model.
from sklearn.metrics import classification_report   # For evaluating the performance.

# Generate a synthetic dataset using the make_moons function.
# This creates two interleaving half circles ("moons") that are ideal for clustering tasks.
X, y = datasets.make_moons(n_samples=200, noise=0.2, random_state=42)
# X contains the 2D features, and y contains the true labels (0 or 1).

# Simulate a partially labeled dataset.
# Here, we randomly mark 70% of the data as unlabeled.
rng = np.random.RandomState(42)            # Create a random number generator with a fixed seed for reproducibility.
random_unlabeled_points = rng.rand(len(y)) < 0.7  # Generate a boolean mask: ~70% True (unlabeled), ~30% False (labeled).

# Make a copy of the original labels to create our training label vector.
y_train = np.copy(y)
# For those data points marked as unlabeled, set their label to -1.
# scikit-learn’s semi-supervised algorithms interpret a label of -1 as "missing label."
y_train[random_unlabeled_points] = -1

# Instantiate the LabelSpreading model.
# LabelSpreading uses graph-based semi-supervised learning with a Gaussian (RBF) kernel.
label_spread = LabelSpreading(kernel='rbf', gamma=20, max_iter=30)
# 'kernel' specifies the similarity function, 'gamma' controls the RBF kernel width,
# and 'max_iter' is the maximum number of iterations for label propagation.

# Fit the LabelSpreading model on the feature data X and our partially labeled targets y_train.
label_spread.fit(X, y_train)
# During training, the model propagates the label information from the labeled to the unlabeled samples.

# After the model has converged, extract the predicted labels (transduction).
y_pred = label_spread.transduction_
# y_pred now contains the inferred labels for all data points in X.

# Visualize the semi-supervised learning result.
plt.figure(figsize=(8, 6))  # Create a new figure with a specified size.
# Plot the data points in X, coloring by the predicted label y_pred.
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y_pred, cmap='coolwarm')
plt.title("Label Spreading - Semi-Supervised Learning")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()  # Display the plot.

# Evaluate the performance of the semi-supervised label propagation.
# Compare the model’s predicted labels with the true labels from our original dataset.
print(classification_report(y, y_pred))
# The classification report shows metrics (precision, recall, f1-score) that help assess how well the labels were propagated.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.94       100
#            1       0.92      0.97      0.95       100
#
#     accuracy                           0.94       200
#    macro avg       0.95      0.95      0.94       200
# weighted avg       0.95      0.94      0.94       200

# %%
import pandas as pd
# Deals with tables and spreadsheets
data=pd.read_csv('PRSA_data_2010.1.1-2014.12.31.csv')
# Now let us handle the missing values
data=data.dropna()
data = pd.get_dummies(data, columns=['cbwd'])
# Feature selection
features = data[['TEMP', 'PRES', 'DEWP', 'Iws', 'Is', 'Ir']]
# We want to actually know how dirty the air is using the above parameters
target = np.log1p(data['pm2.5'])

# Now let us normalize our data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)
# TRAINING TIME
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=1000,random_state=42)
model.fit(X_train,y_train)
# Random forest is like finding smart trees that can help me make smart decisions.
# Now I create the team of 100 smart trees and the random number ensures the results are the same
# X train is clues like temperatures and Y train is the pm2.5 therefore our model should guess the pm2 based on the clues without looking
from sklearn.metrics import mean_absolute_error,r2_score
y_pred=model.predict(X_test)
# y_pred is like the guess the bot is going to make from the clues
print("Mean Absolute Error:",mean_absolute_error(y_test,y_pred))
print("R2 Score:",r2_score(y_test,y_pred))
# Mean absolute error tells us how far we are from the actual answers the smaller the better
# R2 tells us if our findings can interpret real data.If it is 1.o it is genius 0 means ut hasnt learn and below 0 means that our bot became worse
# VISUALIZING
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,alpha=0.5)
plt.xlabel("Actual PM2.5")
plt.ylabel("Predicted PM2.5")
plt.title("Actual vs Predicted PM2.5")
plt.show()
# Out:
# Mean Absolute Error: 0.5548155116093977
# R2 Score: 0.4682417032659638

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load and prepare the data
data = pd.read_csv('PRSA_data_2010.1.1-2014.12.31.csv')
data = data.dropna()
data = pd.get_dummies(data, columns=['cbwd'])

# Add time-based features
data['hour'] = data['hour']
data['month'] = data['month']

# Select features and target
features = data[['TEMP', 'PRES', 'DEWP', 'Iws', 'Is', 'Ir', 'hour', 'month'] +
                [col for col in data.columns if col.startswith('cbwd_')]]
target = np.log1p(data['pm2.5'])  # Use log scale to help the model with large values

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Train the Gradient Boosting model
model = GradientBoostingRegressor(n_estimators=500, learning_rate=0.05, max_depth=6, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))

# Visualize the results
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, label='Predictions')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.xlabel("Actual log(PM2.5)")
plt.ylabel("Predicted log(PM2.5)")
plt.title("Actual vs Predicted PM2.5 (log scale)")
plt.legend()
plt.show()
# Out:
# Mean Absolute Error: 0.43628148990033033
# R2 Score: 0.6791282169287961
